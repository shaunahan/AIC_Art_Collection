# %%
pip install -i https://test.pypi.org/simple/ aic-art-collection
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting aic-art-collection
#   Downloading https://test-files.pythonhosted.org/packages/22/c7/d956f74db4695a447f2e98d92f58371c0b44451eb2e0b5d88d8b3c575741/aic_art_collection-0.2.5-py3-none-any.whl (5.2 kB)
# Installing collected packages: aic-art-collection
# Successfully installed aic-art-collection-0.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall aic_art_collection --y
# Out:
# Found existing installation: aic-art-collection 0.2.4
# Uninstalling aic-art-collection-0.2.4:
#   Successfully uninstalled aic-art-collection-0.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import numpy as np
import json
import requests
import altair as alt
from PIL import Image
from io import BytesIO
from IPython.display import display, HTML
from aic_art_collection import aic_art_collection
import sys

sys.path.append("/Users/user/Documents/fall2022/mds/ivpy/src/")
from ivpy import attach,show
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 10
#       8 from io import BytesIO
#       9 from IPython.display import display, HTML
# ---> 10 from aic_art_collection import aic_art_collection
#      11 import sys
#      13 sys.path.append("/Users/user/Documents/fall2022/mds/ivpy/src/")
#
# File ~/miniforge3/lib/python3.10/site-packages/aic_art_collection/aic_art_collection.py:6
#       4 import json
#       5 import requests
# ----> 6 from ivpy import attach,show
#       7 import altair as alt
#       8 from PIL import Image
#
# ModuleNotFoundError: No module named 'ivpy'

# %%
help(aic_art_collection)
# Out:
# Help on module aic_art_collection.aic_art_collection in aic_art_collection:
#
# NAME
#     aic_art_collection.aic_art_collection
#
# FUNCTIONS
#     get_image(image)
#         A function to print the quried keyword. A user can query artworks by the name of an aritst or by the name of an artwork.
#
#         Parameters:
#         -------------
#         query: str
#             A keyword to query.
#
#         Returns:
#         -------------
#         viz: a collection of images on the queried by a user.
#
#         Example:
#         -------------
#         >>> a visualization of the queried word appeared over time at the Art Institute of Chicago.
#
#     get_museum_tour(tour)
#         Function to retrieve the information about current tours at the Art institute of Chicago.
#
#         Parameters:
#         -------------
#         tour: str
#             A keyword to query; keyword can be any string that indicates a tour name, title of artwork, an exhibition name, or an artist's name.
#
#         Returns:
#         -------------
#         tour_info
#
#         Example:
#         -------------
#         >>> get_museum_tour('cezanne tour')
#             no error (successfully made request)
#                 id  ...                                      artist_titles
#             0  4999  ...  [Paul Cezanne, Paul Cezanne, Paul Cezanne, Pau...
#             1  4989  ...  [Paul Cezanne, Paul Cezanne, Paul Cezanne, Pau...
#             2  2193  ...  [Archibald John Motley Jr., Grant Wood, Olowe ...
#             3  1023  ...                     [Adler & Sullivan, Architects]
#             4  4197  ...  [Archibald John Motley Jr., Felix Gonzalez-Tor...
#             5  5155  ...                                                 []
#             6  3246  ...  [Grant Wood, Olowe of Ise, Yoruba, Aztec (Mexi...
#             7  4551  ...  [Ancient Roman, Ancient Roman, Ancient Mesopot...
#             8  5164  ...                                                 []
#             9  4671  ...  [René Magritte, Max Ernst, Joan Miró, Claude C...
#             [10 rows x 7 columns]
#
#     get_search_artwork(artwork)
#         Retrieve the information about collections in the Art Institute of Chicago
#
#         Parameters:
#         -------------
#         artwork: Write any key word to query. It can be the name of an artist, an artwork, the place where an artwork was created, date, or the type of the work.
#
#         Returns:
#         -------------
#         Status code: str
#             Status code is issued by a server in response to a client's request made to the server.
#
#         Dataframe: df
#             Includes the detailed information about artworks that were queried.
#
#         Example:
#         -------------
#         >>> get_search_artwork('1984')
#             200 OK success response code. The request has succeeded.
#                 id  ...                                    category_titles
#             0  189594  ...                              [Prints and Drawings]
#             1  121115  ...            [Photography and Media, Latin American]
#             2  103026  ...                          [Architecture and Design]
#             3  102229  ...  [Contemporary Art, Chicago Artists, SAIC Alumn...
#             4  185062  ...                            [Photography and Media]
#             5  151231  ...                              [Prints and Drawings]
#             6   76934  ...                            [Photography and Media]
#             7  187165  ...      [Contemporary Art, Essentials, Women artists]
#             8  131385  ...   [Prints and Drawings, Essentials, Women artists]
#             9  212224  ...                            [Photography and Media]
#             [10 rows x 7 columns]
#
#     post_popularity_stat(query)
#         Objects mentioning the queried keyword accessioned to the Art Institute of Chicago
#         This function counts the frequency of the keyword over time.
#
#         Parameters:
#         -------------
#         query: str
#             A keyword to query; keyword can be any string that indicates a tour name, title of artwork, an exhibition name, or an artist's name.
#
#         Returns:
#         -------------
#         chart: a visualization of the frequency of the queried word appeared over time at the Art Institute of Chicago.
#
#         Example:
#         -------------
#         >>> a visualization of the queried word appeared over time at the Art Institute of Chicago.
#
# FILE
#     /Users/user/miniforge3/lib/python3.10/site-packages/aic_art_collection/aic_art_collection.py

# %%
help(aic_art_collection.get_search_artwork)
# Out:
# Help on function get_search_artwork in module aic_art_collection.aic_art_collection:
#
# get_search_artwork(artwork)
#     Retrieve the information about collections in the Art Institute of Chicago
#
#     Parameters:
#     -------------
#     artwork: Write any key word to query. It can be the name of an artist, an artwork, the place where an artwork was created, date, or the type of the work.
#
#     Returns:
#     -------------
#     Status code: str
#         Status code is issued by a server in response to a client's request made to the server.
#
#     Dataframe: df
#         Includes the detailed information about artworks that were queried.
#
#     Example:
#     -------------
#     >>> get_search_artwork('1984')
#         200 OK success response code. The request has succeeded.
#             id  ...                                    category_titles
#         0  189594  ...                              [Prints and Drawings]
#         1  121115  ...            [Photography and Media, Latin American]
#         2  103026  ...                          [Architecture and Design]
#         3  102229  ...  [Contemporary Art, Chicago Artists, SAIC Alumn...
#         4  185062  ...                            [Photography and Media]
#         5  151231  ...                              [Prints and Drawings]
#         6   76934  ...                            [Photography and Media]
#         7  187165  ...      [Contemporary Art, Essentials, Women artists]
#         8  131385  ...   [Prints and Drawings, Essentials, Women artists]
#         9  212224  ...                            [Photography and Media]
#         [10 rows x 7 columns]

# %%
aic_art_collection.get_search_artwork('Henri Matisse')
# Out:
# 200 OK success response code. The request has succeeded.
#        id                                title  \
# 0  117254                       Hommage à H.M.
# 1   79307                   Bathers by a River
# 2   27984             Woman before an Aquarium
# 3    2816                     Interior at Nice
# 4   64001                               Apples
# 5  100226                              Daisies
# 6   87045             Still Life with Geranium
# 7  153703             Lemons on a Pewter Plate
# 8  122232        Laurette with a Cup of Coffee
# 9  191565  Girl in Yellow and Blue with Guitar
#
#                              artist_display place_of_origin  date_start  \
# 0  Helen Frankenthaler\nAmerican, 1928-2011   United States        1971
# 1          Henri Matisse\nFrench, 1869–1954          France        1909
# 2          Henri Matisse\nFrench, 1869–1954          France        1921
# 3          Henri Matisse\nFrench, 1869–1954          France        1919
# 4          Henri Matisse\nFrench, 1869–1954          France        1916
# 5          Henri Matisse\nFrench, 1869–1954          France        1939
# 6          Henri Matisse\nFrench, 1869–1954          France        1906
# 7          Henri Matisse\nFrench, 1869–1954          France        1926
# 8          Henri Matisse\nFrench, 1869–1954          France        1916
# 9          Henri Matisse\nFrench, 1869–1954            None        1939
#
#    date_end     medium_display                                category_titles
# 0      1971  Acrylic on canvas              [Contemporary Art, Women artists]
# 1      1917      Oil on canvas  [Modern Art, Art Institute Icons, Essentials]
# 2      1923      Oil on canvas                       [Modern Art, Essentials]
# 3      1920      Oil on canvas                       [Modern Art, Essentials]
# 4      1916      Oil on canvas                                   [Modern Art]
# 5      1939      Oil on canvas                                   [Modern Art]
# 6      1906      Oil on canvas                       [Modern Art, Essentials]
# 7      1926      Oil on canvas                                   [Modern Art]
# 8      1916      Oil on canvas                                   [Modern Art]
# 9      1939      Oil on canvas                                   [Modern Art]

# %%
help(aic_art_collection.get_museum_tour)
# Out:
# Help on function get_museum_tour in module aic_art_collection.aic_art_collection:
#
# get_museum_tour(tour)
#     Function to retrieve the information about current tours at the Art institute of Chicago.
#
#     Parameters:
#     -------------
#     tour: str
#         A keyword to query; keyword can be any string that indicates a tour name, title of artwork, an exhibition name, or an artist's name.
#
#     Returns:
#     -------------
#     tour_info
#
#     Example:
#     -------------
#     >>> get_museum_tour('cezanne tour')
#         no error (successfully made request)
#             id  ...                                      artist_titles
#         0  4999  ...  [Paul Cezanne, Paul Cezanne, Paul Cezanne, Pau...
#         1  4989  ...  [Paul Cezanne, Paul Cezanne, Paul Cezanne, Pau...
#         2  2193  ...  [Archibald John Motley Jr., Grant Wood, Olowe ...
#         3  1023  ...                     [Adler & Sullivan, Architects]
#         4  4197  ...  [Archibald John Motley Jr., Felix Gonzalez-Tor...
#         5  5155  ...                                                 []
#         6  3246  ...  [Grant Wood, Olowe of Ise, Yoruba, Aztec (Mexi...
#         7  4551  ...  [Ancient Roman, Ancient Roman, Ancient Mesopot...
#         8  5164  ...                                                 []
#         9  4671  ...  [René Magritte, Max Ernst, Joan Miró, Claude C...
#         [10 rows x 7 columns]

# %%
aic_art_collection.get_museum_tour('Tour')
# Out:
# no error (successfully made request)
#      id                                              title  \
# 0  2193                                The Essentials Tour
# 1  1023                              The Architecture Tour
# 2  4197                                      The Teen Tour
# 3  4999                    Cezanne Verbal Description Tour
# 4  5155               Sophie Calle Verbal Description Tour
# 5  3246            Verbal Description tour: The Essentials
# 6  4551                                   Myth and Scandal
# 7  5164              The Language of Beauty in African Art
# 8  4671                   How to Make a Surrealist Artwork
# 9  4235  Life, Death, and Salvation: Stories of the Ren...
#
#                                                image  \
# 0  http://aic-mobile-tours.artic.edu/sites/defaul...
# 1  http://aic-mobile-tours.artic.edu/sites/defaul...
# 2  http://aic-mobile-tours.artic.edu/sites/defaul...
# 3  http://aic-mobile-tours.artic.edu/sites/defaul...
# 4  http://aic-mobile-tours.artic.edu/sites/defaul...
# 5  http://aic-mobile-tours.artic.edu/sites/defaul...
# 6  http://aic-mobile-tours.artic.edu/sites/defaul...
# 7  http://aic-mobile-tours.artic.edu/sites/defaul...
# 8  http://aic-mobile-tours.artic.edu/sites/defaul...
# 9  http://aic-mobile-tours.artic.edu/sites/defaul...
#
#                                          description  \
# 0  <p>Discover the stories behind some of the mus...
# 1  <p>Uncover the secrets of the museum’s storied...
# 2  <p>Experience the museum through sounds and st...
# 3  <p>Designed for people with impaired vision: D...
# 4  <p>Designed for people with impaired vision, b...
# 5  <p>Designed for people with impaired vision: D...
# 6  <p>The Myth and Scandal tour tells some of the...
# 7  <p>The Language of Beauty in African Art audio...
# 8  <p>Can a wine rack be a work of art? How can d...
# 9  <p>Come learn how Reliquaries were used as sid...
#
#                                                intro  \
# 0  <p>Indulge in the sunlit bank of the River Sei...
# 1  <p>The Art Institute of Chicago reaches across...
# 2  <p>Expand your perspective on the Grand Stairc...
# 3  <p>This verbal description tour is designed fo...
# 4  <p>“I met people who were born blind. Who had ...
# 5  <p>Bask on the sunlit bank of the Seine in Geo...
# 6  <p>Come learn about the juicy histories and ch...
# 7  <p>This tour features a collection of perspect...
# 8  <p>What lies beneath the surface of consciousn...
# 9  <p>On this tour, curators Martha Wolff and Reb...
#
#                                       artwork_titles  \
# 0  [Nightlife, American Gothic, Veranda Post (Òpó...
# 1  [Chicago Stock Exchange Trading Room: Reconstr...
# 2  [Nightlife, "Untitled", America Windows, Paper...
# 3  [Auvers, Panoramic View, The Three Skulls, Mad...
# 4                                                 []
# 5  [American Gothic, Veranda Post (Òpó Ògògá), Co...
# 6  [Statue of Young Dionysos, Statue of the Aphro...
# 7                                                 []
# 8  [Time Transfixed, Forest and Sun, The Policema...
# 9  [Wine Cistern, Reliquary Monstrance with a Too...
#
#                                        artist_titles
# 0  [Archibald John Motley Jr., Grant Wood, Olowe ...
# 1                     [Adler & Sullivan, Architects]
# 2  [Archibald John Motley Jr., Felix Gonzalez-Tor...
# 3  [Paul Cezanne, Paul Cezanne, Paul Cezanne, Pau...
# 4                                                 []
# 5  [Grant Wood, Olowe of Ise, Yoruba, Aztec (Mexi...
# 6  [Ancient Roman, Ancient Roman, Ancient Mesopot...
# 7                                                 []
# 8  [René Magritte, Max Ernst, Joan Miró, Claude C...
# 9  [Francesco Durantino, Weddeghe Velstede, Berna...

# %%
help(aic_art_collection.post_popularity_stat)
# Out:
# Help on function post_popularity_stat in module aic_art_collection.aic_art_collection:
#
# post_popularity_stat(query)
#     Objects mentioning the queried keyword accessioned to the Art Institute of Chicago
#     This function counts the frequency of the keyword over time.
#
#     Parameters:
#     -------------
#     query: str
#         A keyword to query; keyword can be any string that indicates a tour name, title of artwork, an exhibition name, or an artist's name.
#
#     Returns:
#     -------------
#     chart: a visualization of the frequency of the queried word appeared over time at the Art Institute of Chicago.
#
#     Example:
#     -------------
#     >>> a visualization of the queried word appeared over time at the Art Institute of Chicago.

# %%
aic_art_collection.post_popularity_stat('France')
# Out:
# /Users/user/miniforge3/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
from ivpy import attach,show

aic_art_collection.get_image('France')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 from ivpy import attach,show
#       3 aic_art_collection.get_image('France')
#
# ImportError: cannot import name 'attach' from 'ivpy' (unknown location)
